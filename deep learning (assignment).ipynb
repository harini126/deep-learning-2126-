# %%
import matplotlib.pyplot as plt
import math as m
import numpy as np

# %%
# 3)  a) solution 

# h11(x) plotting 

x1=np.linspace(-1,1,100)
a1=np.exp(-(500*x)-30)
y1= 1/(1+a1) 
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
ax1.spines['left'].set_position('center')
ax1.spines['bottom'].set_position('zero')
ax1.spines['right'].set_color('none')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

plt.plot(x1,y1,'r')
plt.show()

# %%
# h12(x) plotting 


x=np.linspace(-1,1,100)
a=np.exp(-(500*x)+30)
y= 1/(1+a) 
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(x,y,'r')
plt.show()

# %%
# h21(x) plotting 


x2=np.linspace(-1,1,100)
a=np.exp(-(500*x2)+30)
a1=np.exp(-(500*x2)-30)
z=(1/(1+a1))-(1/(1+a))
fig=plt.figure()
ax2=fig.add_subplot(1,1,1)
ax2.spines['left'].set_position('center')
ax2.spines['bottom'].set_position('zero')
ax2.spines['right'].set_color('none')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

plt.plot(x2,z,'r')
plt.show()

# %%
# 3)  b) solution 


# h11(x) plotting 

x1=np.linspace(-5,5,10)
x2=np.linspace(-5,5,10)
a=np.exp(-(x1+50*x2+100))
y1= 1/(1+a) 
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(x1,x2,y1)

# %%
#h12(x) plotting


x1=np.linspace(-5,5,10)
x2=np.linspace(-5,5,10)
a=np.exp(-(x1+50*x2-100))
y1= 1/(1+a) 
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(x1,x2,y1)

# %%
#h13(x) plotting


x1=np.linspace(-5,5,10)
x2=np.linspace(-5,5,10)
a=np.exp(-(50*x1+x2+100))
y1= 1/(1+a) 
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(x1,x2,y1)

# %%
#h14 plotting

x1=np.linspace(-5,5,10)
x2=np.linspace(-5,5,10)
a=np.exp(-(50*x1+x2-100))
y1= 1/(1+a) 
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(x1,x2,y1)

# %%
#h21(x1,x2) plotting


x1=np.linspace(-5,5,10)
x2=np.linspace(-5,5,10)
a=np.exp(-(x1+50*x2+100))
a1=np.exp(-(x1+50*x2-100))
z=(1/(1+a))-(1/(1+a1))
fig=plt.figure()
ax2=fig.add_subplot(1,1,1)
ax2.spines['left'].set_position('center')
ax2.spines['bottom'].set_position('zero')
ax2.spines['right'].set_color('none')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

plt.plot(x1,x2,z)

# %%
#h22(x1,x2) plotting


x1=np.linspace(-5,5,100)
x2=np.linspace(-5,5,100)
a=np.exp(-(50*x1+x2+100))
a1=np.exp(-(50*x1+x2-100))
z=(1/(1+a))-(1/(1+a1))
fig=plt.figure()
ax2=fig.add_subplot(1,1,1)
ax2.spines['left'].set_position('center')
ax2.spines['bottom'].set_position('zero')
ax2.spines['right'].set_color('none')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

plt.plot(x1,x2,z)

# %%
#h31(x1,x2) plotting

x1=np.linspace(-5,5,100)
x2=np.linspace(-5,5,100)
a1=np.exp(-(x1+50*x2+100))
a2=np.exp(-(x1+50*x2-100))
a=np.exp(-(50*x1+x2+100))
a3=np.exp(-(50*x1+x2-100))
z=(1/(1+a))-(1/(1+a3))+(1/(1+a1))-(1/(1+a2))
fig=plt.figure()
ax2=fig.add_subplot(1,1,1)
ax2.spines['left'].set_position('center')
ax2.spines['bottom'].set_position('zero')
ax2.spines['right'].set_color('none')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

plt.plot(x1,x2,z)

# %%
#f(x1,x2) plotting

x1=np.linspace(-5,5,100)
x2=np.linspace(-5,5,100)
a1=np.exp(-(x1+50*x2+100))
a2=np.exp(-(x1+50*x2-100))
a=np.exp(-(50*x1+x2+100))
a3=np.exp(-(50*x1+x2-100))
z=(1/(1+a))-(1/(1+a3))+(1/(1+a1))-(1/(1+a2))
l=np.exp(-(100*z-200))
z1=(1/(1+l))
fig=plt.figure()
ax2=fig.add_subplot(1,1,1)
ax2.spines['left'].set_position('center')
ax2.spines['bottom'].set_position('zero')
ax2.spines['right'].set_color('none')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
plt.plot(x1,x2,l)
